# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
energydata = pd.read_csv('energydata_complete.csv')
energydata.head()
# Out:
#               date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  1/11/2016 17:00          60      30  19.89  47.596667  19.2  44.790000
# 1  1/11/2016 17:10          60      30  19.89  46.693333  19.2  44.722500
# 2  1/11/2016 17:20          50      30  19.89  46.300000  19.2  44.626667
# 3  1/11/2016 17:30          50      40  19.89  46.066667  19.2  44.590000
# 4  1/11/2016 17:40          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9  T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53   6.60        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56   6.48        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50   6.37        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40   6.25        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40   6.13        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# ...

# %%
energydata.shape
# Out:
# (19735, 29)

# %%
pd.options.display.max_columns = 30
energydata.head()
# Out:
#               date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  1/11/2016 17:00          60      30  19.89  47.596667  19.2  44.790000
# 1  1/11/2016 17:10          60      30  19.89  46.693333  19.2  44.722500
# 2  1/11/2016 17:20          50      30  19.89  46.300000  19.2  44.626667
# 3  1/11/2016 17:30          50      40  19.89  46.066667  19.2  44.590000
# 4  1/11/2016 17:40          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4       RH_4         T5   RH_5        T6  \
# 0  19.79  44.730000  19.000000  45.566667  17.166667  55.20  7.026667
# 1  19.79  44.790000  19.000000  45.992500  17.166667  55.20  6.833333
# 2  19.79  44.933333  18.926667  45.890000  17.166667  55.09  6.560000
# 3  19.79  45.000000  18.890000  45.723333  17.166667  55.09  6.433333
# 4  19.79  45.000000  18.890000  45.530000  17.200000  55.09  6.366667
#
#         RH_6         T7       RH_7    T8       RH_8         T9   RH_9  T_out  \
# ...

# %%
energydata.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
energydata.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
#Data visualization

energydata.hist(bins=20, figsize=(20,20));

# %%
#drop date and lights columns

energydata.drop(['date'], axis=1, inplace=True)

# %%
energydata.drop(['lights'], axis=1, inplace=True)

# %%
#Normalize the dataset using MinMaxScalar

from sklearn.preprocessing import MinMaxScaler
scaler =MinMaxScaler()
normalised_energydata = pd.DataFrame(scaler.fit_transform(energydata), columns=energydata.columns)
features = normalised_energydata.drop(columns=['Appliances'])
response = normalised_energydata['Appliances']

# %%
#From the dataset, fit a linear model on the relationship between the temperature in the living room in Celsius (x = T2) and the temperature outside the building (y = T6).
energydata.plot(x='T2', y='T6', style='o')  
plt.title('T2 vs T6')  
plt.xlabel('T2')  
plt.ylabel('T6')  
plt.show()

# %%
T2 = energydata.T2
T6 = energydata.T6

correlation_matrix = np.corrcoef(T2,T6)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2

print(r_squared)
# Out:
# 0.6418990830813065

# %%
#Now, we split our dataset into the training and testing dataset.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, response, test_size = 0.3, random_state=42)

from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
#fit the model to the training dataset
linear_model.fit(x_train, y_train)


print(linear_model.intercept_)
print(linear_model.coef_)


#obtain predictions
predicted_values = linear_model.predict(x_test)
# Out:
# 0.1529713951405547
# [-0.00324164  0.55351643 -0.23619824 -0.45666207  0.29058676  0.09609469
#   0.028957    0.02637035 -0.01564516  0.01600901  0.23644073  0.03802267
#   0.01034977 -0.0446198   0.10199549 -0.15758506 -0.18997749 -0.03980848
#  -0.32196857  0.00683206 -0.07774848  0.02917819  0.01230582  0.11786204
#   0.00076517  0.00076517]

# %%
#MAE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 2)
# Out:
# 0.05

# %%
#residual sum of squares.py
import numpy as np
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 2)
# Out:
# 45.35

# %%
#Root mean square error.py
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.088

# %%
#R-Squared.py
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 2)
# Out:
# 0.15

# %%
#Ridge Regression

from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.5)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
#feature selection and lasso regression
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
#comparing the effects of regularisation
def get_weights_energydata(model, feat, col_name):
    #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_energydata = pd.DataFrame(weights).reset_index()
    weights_energydata.columns = ['Features', col_name]
    weights_energydata[col_name].round(3)
    return weights_energydata

# %%
linear_model_weights = get_weights_energydata(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_energydata = get_weights_energydata(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_energydata = get_weights_energydata(lasso_reg, x_train, 'Lasso_Weight')

final_weights = pd.merge(linear_model_weights, ridge_weights_energydata, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_energydata, on='Features')

print(final_weights)
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_Weight
# 0          RH_2            -0.456662     -0.401113     -0.000000
# 1         T_out            -0.321969     -0.250943      0.000000
# 2            T2            -0.236198     -0.193899      0.000000
# 3            T9            -0.189977     -0.188615     -0.000000
# 4          RH_8            -0.157585     -0.156584     -0.000110
# 5        RH_out            -0.077748     -0.050642     -0.049557
# 6          RH_7            -0.044620     -0.046297     -0.000000
# 7          RH_9            -0.039808     -0.041707     -0.000000
# 8            T5            -0.015645     -0.020714     -0.000000
# 9            T1            -0.003242     -0.021515      0.000000
# 10          rv2             0.000765      0.000740     -0.000000
# 11          rv1             0.000765      0.000740     -0.000000
# 12  Press_mm_hg             0.006832      0.006511     -0.000000
# ...

# %%
#Obtain the feature weights from your linear model above, lowest
linear_model_weights.min()
# Out:
# Features               Press_mm_hg
# Linear_Model_Weight      -0.456662
# dtype: object

# %%
#Obtain the feature weights from your linear model above, Highest
linear_model_weights.max()
# Out:
# Features                    rv2
# Linear_Model_Weight    0.553516
# dtype: object

# %%
#Train a ridge regression model with an alpha value of 0.4
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
#Root mean square error.py at alpha = 0.4
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.088

# %%
#feature selection and lasso regression
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
#Root mean square error.py at alpha = 0.4
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, lasso_weights_energydata))
round(rmse, 3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-982bc36f2f07> in <module>
#       1 #Root mean square error.py at alpha = 0.4
#       2 from sklearn.metrics import mean_squared_error
# ----> 3 rmse = np.sqrt(mean_squared_error(y_test, lasso_weights_energydata))
#       4 round(rmse, 3)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     250     """
#     251     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 252         y_true, y_pred, multioutput)
#     253     check_consistent_length(y_true, y_pred, sample_weight)
#     254     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ...

# %%
lasso_weights_energydata = get_weights_energydata(lasso_reg, x_train, 'Lasso_Weight')
lasso_weights_energydata
# Out:
#        Features  Lasso_Weight
# 0        RH_out     -0.049557
# 1          RH_8     -0.000110
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4     -0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.002912
# 25         RH_1      0.017880

# %%
np.count_nonzero(lasso_weights_energydata)
# Out:
# 30
